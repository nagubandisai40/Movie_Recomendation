# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('E:\study\data science\Movie Recommendation System\ml-latest-small\\ratings.csv')
movies=pd.read_csv('E:\study\data science\Movie Recommendation System\ml-latest-small\movies.csv')
df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# ...

# %%
df
# Out:
#         userId  movieId  rating   timestamp  \
# 0            1        1     4.0   964982703
# 1            5        1     4.0   847434962
# 2            7        1     4.5  1106635946
# 3           15        1     2.5  1510577970
# 4           17        1     4.5  1305696483
# 5           18        1     3.5  1455209816
# 6           19        1     4.0   965705637
# 7           21        1     3.5  1407618878
# 8           27        1     3.0   962685262
# 9           31        1     5.0   850466616
# 10          32        1     3.0   856736119
# 11          33        1     3.0   939647444
# 12          40        1     5.0   832058959
# 13          43        1     5.0   848993983
# 14          44        1     3.0   869251860
# 15          45        1     4.0   951170182
# 16          46        1     5.0   834787906
# 17          50        1     3.0  1514238116
# 18          54        1     3.0   830247330
# 19          57        1     5.0   965796031
# ...

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False)
# Out:
# title
# Karlson Returns (1970)                                5.0
# Winter in Prostokvashino (1984)                       5.0
# My Love (2006)                                        5.0
# Sorority House Massacre II (1990)                     5.0
# Winnie the Pooh and the Day of Concern (1972)         5.0
# Sorority House Massacre (1986)                        5.0
# Bill Hicks: Revelations (1993)                        5.0
# My Man Godfrey (1957)                                 5.0
# Hellbenders (2012)                                    5.0
# In the blue sea, in the white foam. (1984)            5.0
# Won't You Be My Neighbor? (2018)                      5.0
# Red Sorghum (Hong gao liang) (1987)                   5.0
# Love Exposure (Ai No Mukidashi) (2008)                5.0
# My Sassy Girl (Yeopgijeogin geunyeo) (2001)           5.0
# The Love Bug (1997)                                   5.0
# Ballad of Narayama, The (Narayama bushiko) (1983)     5.0
# ...

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
mean_rating=df.groupby('title')['rating'].mean()

# %%
count_rating=df.groupby('title')['rating'].count().sort_values(ascending=False)

# %%
mean_rating.hist(bins=70)

# %%
count_rating.hist(bins=70)

# %%
pivot=df.pivot_table('rating',index='userId',columns='title')

# %%
pivot
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# 6              NaN                                      NaN
# 7              NaN                                      NaN
# 8              NaN                                      NaN
# 9              NaN                                      NaN
# 10             NaN                                      NaN
# 11             NaN                                      NaN
# 12             NaN                                      NaN
# 13             NaN                                      NaN
# 14             NaN                                      NaN
# ...

# %%
temp1=pivot["[REC] (2007)"]

# %%
temp1
# Out:
# userId
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
#       ...
# 581    NaN
# 582    NaN
# 583    NaN
# 584    NaN
# 585    NaN
# 586    NaN
# 587    NaN
# 588    NaN
# 589    NaN
# 590    NaN
# 591    NaN
# 592    NaN
# 593    NaN
# 594    NaN
# 595    NaN
# 596    NaN
# 597    NaN
# 598    NaN
# 599    NaN
# 600    NaN
# 601    NaN
# 602    NaN
# 603    NaN
# 604    NaN
# 605    NaN
# 606    NaN
# 607    NaN
# 608    NaN
# 609    NaN
# 610    4.0
# Name: [REC] (2007), Length: 610, dtype: float64

# %%
pivot.corrwith(temp1).sort_values(ascending=False)
# Out:
# title
# Beyond the Mat (1999)                                                                       1.0
# Rush (2013)                                                                                 1.0
# Grudge, The (2004)                                                                          1.0
# Cinderella (1950)                                                                           1.0
# Christmas Vacation (National Lampoon's Christmas Vacation) (1989)                           1.0
# Christmas Story, A (1983)                                                                   1.0
# Ant-Man (2015)                                                                              1.0
# Shaolin Soccer (Siu lam juk kau) (2001)                                                     1.0
# Seed of Chucky (Child's Play 5) (2004)                                                      1.0
# Haunting, The (1999)                                                                        1.0
# ...
